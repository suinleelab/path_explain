# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import altair as alt
import shap

from marginal import MarginalExplainer
import plot

# %%
n = 5000
d = 6
hidden_layers = 100
batch_size = 50
learning_rate = 0.035

# %%
X = np.random.randn(n, d)
y = np.sum(X, axis=-1) + X[:, 0] * X[:, 1] + X[:, 0] * X[:, 2] + 2 * X[:, 0] * X[:, 1] * X[:, 2]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(d,), batch_size=batch_size))
model.add(tf.keras.layers.Dense(hidden_layers, activation=tf.keras.activations.relu, use_bias=True))
model.add(tf.keras.layers.Dense(hidden_layers, activation=tf.keras.activations.relu, use_bias=True))
model.add(tf.keras.layers.Dense(1, activation=None, use_bias=False))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MSE,
              metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanSquaredError()])

# %%
model.fit(X, y, epochs=30, verbose=2)
# Out:
# Train on 5000 samples
# Epoch 1/30
# 5000/5000 - 1s - loss: 4.5958 - mean_absolute_error: 1.2590 - mean_squared_error: 4.5958
# Epoch 2/30
# 5000/5000 - 0s - loss: 1.9603 - mean_absolute_error: 0.8231 - mean_squared_error: 1.9603
# Epoch 3/30
# 5000/5000 - 0s - loss: 1.1454 - mean_absolute_error: 0.6457 - mean_squared_error: 1.1454
# Epoch 4/30
# 5000/5000 - 0s - loss: 0.8668 - mean_absolute_error: 0.5681 - mean_squared_error: 0.8668
# Epoch 5/30
# 5000/5000 - 0s - loss: 0.6592 - mean_absolute_error: 0.4843 - mean_squared_error: 0.6592
# Epoch 6/30
# 5000/5000 - 0s - loss: 0.5135 - mean_absolute_error: 0.4166 - mean_squared_error: 0.5135
# Epoch 7/30
# 5000/5000 - 0s - loss: 0.5007 - mean_absolute_error: 0.4081 - mean_squared_error: 0.5007
# Epoch 8/30
# 5000/5000 - 0s - loss: 0.2904 - mean_absolute_error: 0.3212 - mean_squared_error: 0.2904
# Epoch 9/30
# 5000/5000 - 0s - loss: 0.2849 - mean_absolute_error: 0.3187 - mean_squared_error: 0.2849
# Epoch 10/30
# 5000/5000 - 0s - loss: 0.1878 - mean_absolute_error: 0.2674 - mean_squared_error: 0.1878
# Epoch 11/30
# 5000/5000 - 0s - loss: 0.1813 - mean_absolute_error: 0.2607 - mean_squared_error: 0.1813
# Epoch 12/30
# 5000/5000 - 0s - loss: 0.1478 - mean_absolute_error: 0.2379 - mean_squared_error: 0.1478
# Epoch 13/30
# 5000/5000 - 0s - loss: 0.1368 - mean_absolute_error: 0.2346 - mean_squared_error: 0.1368
# Epoch 14/30
# 5000/5000 - 0s - loss: 0.1549 - mean_absolute_error: 0.2433 - mean_squared_error: 0.1549
# Epoch 15/30
# 5000/5000 - 0s - loss: 0.1802 - mean_absolute_error: 0.2461 - mean_squared_error: 0.1802
# Epoch 16/30
# 5000/5000 - 0s - loss: 0.1231 - mean_absolute_error: 0.2188 - mean_squared_error: 0.1231
# Epoch 17/30
# 5000/5000 - 0s - loss: 0.0979 - mean_absolute_error: 0.1923 - mean_squared_error: 0.0979
# Epoch 18/30
# 5000/5000 - 0s - loss: 0.1084 - mean_absolute_error: 0.2110 - mean_squared_error: 0.1084
# Epoch 19/30
# 5000/5000 - 0s - loss: 0.0836 - mean_absolute_error: 0.1806 - mean_squared_error: 0.0836
# Epoch 20/30
# 5000/5000 - 0s - loss: 0.0780 - mean_absolute_error: 0.1797 - mean_squared_error: 0.0780
# Epoch 21/30
# 5000/5000 - 0s - loss: 0.0883 - mean_absolute_error: 0.1949 - mean_squared_error: 0.0883
# Epoch 22/30
# 5000/5000 - 0s - loss: 0.0815 - mean_absolute_error: 0.1831 - mean_squared_error: 0.0815
# Epoch 23/30
# 5000/5000 - 0s - loss: 0.1027 - mean_absolute_error: 0.1937 - mean_squared_error: 0.1027
# Epoch 24/30
# 5000/5000 - 0s - loss: 0.0630 - mean_absolute_error: 0.1628 - mean_squared_error: 0.0630
# Epoch 25/30
# 5000/5000 - 0s - loss: 0.0500 - mean_absolute_error: 0.1472 - mean_squared_error: 0.0500
# Epoch 26/30
# 5000/5000 - 0s - loss: 0.0567 - mean_absolute_error: 0.1580 - mean_squared_error: 0.0567
# Epoch 27/30
# 5000/5000 - 0s - loss: 0.0540 - mean_absolute_error: 0.1529 - mean_squared_error: 0.0540
# Epoch 28/30
# 5000/5000 - 0s - loss: 0.0538 - mean_absolute_error: 0.1583 - mean_squared_error: 0.0538
# Epoch 29/30
# 5000/5000 - 0s - loss: 0.0533 - mean_absolute_error: 0.1531 - mean_squared_error: 0.0533
# Epoch 30/30
# 5000/5000 - 0s - loss: 0.0393 - mean_absolute_error: 0.1321 - mean_squared_error: 0.0393

# %%
num_shap_samples=100

# %%
primal_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='mobius')
primal_effects = primal_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]WARNING: Logging before flag parsing goes to stderr.
# W1022 17:28:58.688214 139765826606912 base_layer.py:1814] Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 100%|██████████| 100/100 [00:16<00:00,  6.02it/s]

# %%
dual_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='comobius')
dual_effects = dual_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
# 100%|██████████| 100/100 [00:16<00:00,  6.19it/s]

# %%
average_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='average')
average_effects = average_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
# 100%|██████████| 100/100 [00:30<00:00,  3.25it/s]

# %%
model_func = lambda x: model(x).numpy()
kernel_explainer = shap.SamplingExplainer(model_func, X)
kernel_shap = kernel_explainer.shap_values(X[:num_shap_samples])
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
def unroll(x):
    ret = []
    for i in range(x.shape[-1]):
        ret.append(x[:, i])
    return np.concatenate(ret)

# %%
data_df = pd.DataFrame({
    'Sampled Primal Effects':  unroll(primal_effects),
    'Sampled Dual Effects':    unroll(dual_effects),
    'Sampled Average Effects': unroll(average_effects),
    'Kernel SHAP Values':      unroll(kernel_shap),
    'Primal Interaction Effects':  unroll(kernel_shap - primal_effects),
    'Dual Interaction Effects':    unroll(kernel_shap - dual_effects),
    'Average Interaction Effects': unroll(kernel_shap - average_effects),
    'Feature': [int(i / num_shap_samples) for i in range(num_shap_samples * d)],
    'Feature Value': unroll(X[:num_shap_samples])
})

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Sampled Primal Effects:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Kernel SHAP Values:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Primal Interaction Effects:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
plot.summary_plot(kernel_shap, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
plot.summary_plot(primal_effects, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
plot.summary_plot(kernel_shap - primal_effects, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
ind_df = pd.DataFrame({
    'Primal Main Effect': primal_effects[0],
    'Interaction Effect': kernel_shap[0] - primal_effects[0],
    'Feature': np.arange(kernel_shap.shape[1])
})

melted_df = pd.melt(ind_df, id_vars=['Feature'], value_name='Kernel SHAP Value', var_name='Effect Type')

# %%
alt.Chart(melted_df).mark_bar().encode(
    alt.X('sum(Kernel SHAP Value):Q'),
    alt.Y('Feature:N', sort=alt.EncodingSortField(
            field="Kernel SHAP Value",
            order="descending" 
        ))
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(melted_df).mark_bar().encode(
    alt.X('Kernel SHAP Value:Q'),
    alt.Y('Feature:N', sort=[5, 4, 2, 0, 3, 1]),
    alt.Color('Effect Type:N', scale=alt.Scale(scheme='dark2'))
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
