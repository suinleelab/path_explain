# %%
import numpy as np
import tensorflow as tf
import shap
import matplotlib.pyplot as plt

# %%
baseline = 'black'
primal_effects = np.load('../data/mnist/train/primal_effects_{}.npy'.format(baseline))
shap_values    = np.load('../data/mnist/train/shap_values_{}.npy'.format(baseline))
interaction_effects = np.load('../data/mnist/train/interaction_effects_{}.npy'.format(baseline))

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
shap.image_plot(primal_effects[:5, :, : ,0], -x_train[:5].astype(np.float32))

# %%
shap.image_plot(shap_values[:5, :, : ,0], -x_train[:5].astype(np.float32))

# %%
shap.image_plot(interaction_effects[:5, :, : ,0], -x_train[:5].astype(np.float32))
