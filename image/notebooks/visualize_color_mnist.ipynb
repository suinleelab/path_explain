# %%
import numpy as np
import tensorflow as tf
import shap
import matplotlib.pyplot as plt
from interaction_effects import run_image, utils

# %%
from absl import app
from absl import flags

FLAGS = flags.FLAGS

flags.DEFINE_string('f', '', 'Default')
try:
    app.run(lambda x: None)
except:
    pass

# %%
FLAGS.dataset = 'color_mnist'

# %%
x_train, y_train, x_test, y_test = run_image.get_data()
x_train = utils.normalize(x_train)
x_test = utils.normalize(x_test)

# %%
baseline = 'black'
primal_effects = np.load('../data/color_mnist/test/primal_effects_{}.npy'.format(baseline))
shap_values    = np.load('../data/color_mnist/test/shap_values_{}.npy'.format(baseline))
interaction_effects = np.load('../data/color_mnist/test/interaction_effects_{}.npy'.format(baseline))

# %%
shap.image_plot(shap_values[:5, :, : ,0], x_test[:5].astype(np.float32))

# %%
shap.image_plot(primal_effects[:5, :, : ,0], x_test[:5].astype(np.float32))

# %%
shap.image_plot(interaction_effects[:5, :, : ,0], x_test[:5].astype(np.float32))
