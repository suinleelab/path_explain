# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import altair as alt
import shap

from marginal import MarginalExplainer
import plot

# %%
n = 5000
d = 6
hidden_layers = 100
batch_size = 50
learning_rate = 0.02

# %%
W = np.random.uniform(-5, 5, d)
b = 0.0
mu = np.zeros(d)
cov = np.eye(6)
cov[2, 3] = 0.5
cov[3, 2] = 0.5

X = np.random.multivariate_normal(mu, cov, size=n)
y = np.sum(X[:, 1:], axis=-1) + X[:, 0] * X[:, 1] + X[:, 0] * X[:, 2] + 2 * X[:, 0] * X[:, 1] * X[:, 2]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(d,), batch_size=batch_size))
model.add(tf.keras.layers.Dense(hidden_layers, activation=tf.keras.activations.relu, use_bias=True))
model.add(tf.keras.layers.Dense(hidden_layers, activation=tf.keras.activations.relu, use_bias=True))
model.add(tf.keras.layers.Dense(1, activation=None, use_bias=False))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MSE,
              metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanSquaredError()])

# %%
model.fit(X, y, epochs=30, verbose=2)
# Out:
# Train on 5000 samples
# Epoch 1/30
# 5000/5000 - 1s - loss: 4.4580 - mean_absolute_error: 1.2125 - mean_squared_error: 4.4580
# Epoch 2/30
# 5000/5000 - 0s - loss: 2.4575 - mean_absolute_error: 0.8783 - mean_squared_error: 2.4575
# Epoch 3/30
# 5000/5000 - 0s - loss: 1.4860 - mean_absolute_error: 0.6941 - mean_squared_error: 1.4860
# Epoch 4/30
# 5000/5000 - 0s - loss: 1.0771 - mean_absolute_error: 0.6138 - mean_squared_error: 1.0771
# Epoch 5/30
# 5000/5000 - 0s - loss: 0.8771 - mean_absolute_error: 0.5571 - mean_squared_error: 0.8771
# Epoch 6/30
# 5000/5000 - 0s - loss: 0.6884 - mean_absolute_error: 0.4862 - mean_squared_error: 0.6884
# Epoch 7/30
# 5000/5000 - 0s - loss: 0.6259 - mean_absolute_error: 0.4687 - mean_squared_error: 0.6259
# Epoch 8/30
# 5000/5000 - 0s - loss: 0.5211 - mean_absolute_error: 0.4188 - mean_squared_error: 0.5211
# Epoch 9/30
# 5000/5000 - 0s - loss: 0.4153 - mean_absolute_error: 0.3788 - mean_squared_error: 0.4153
# Epoch 10/30
# 5000/5000 - 0s - loss: 0.4083 - mean_absolute_error: 0.3739 - mean_squared_error: 0.4083
# Epoch 11/30
# 5000/5000 - 0s - loss: 0.3267 - mean_absolute_error: 0.3294 - mean_squared_error: 0.3267
# Epoch 12/30
# 5000/5000 - 0s - loss: 0.3050 - mean_absolute_error: 0.3271 - mean_squared_error: 0.3050
# Epoch 13/30
# 5000/5000 - 0s - loss: 0.2747 - mean_absolute_error: 0.3065 - mean_squared_error: 0.2747
# Epoch 14/30
# 5000/5000 - 0s - loss: 0.2480 - mean_absolute_error: 0.2930 - mean_squared_error: 0.2480
# Epoch 15/30
# 5000/5000 - 0s - loss: 0.2052 - mean_absolute_error: 0.2658 - mean_squared_error: 0.2052
# Epoch 16/30
# 5000/5000 - 0s - loss: 0.1981 - mean_absolute_error: 0.2646 - mean_squared_error: 0.1981
# Epoch 17/30
# 5000/5000 - 0s - loss: 0.1651 - mean_absolute_error: 0.2505 - mean_squared_error: 0.1651
# Epoch 18/30
# 5000/5000 - 0s - loss: 0.1606 - mean_absolute_error: 0.2452 - mean_squared_error: 0.1606
# Epoch 19/30
# 5000/5000 - 0s - loss: 0.1991 - mean_absolute_error: 0.2683 - mean_squared_error: 0.1991
# Epoch 20/30
# 5000/5000 - 0s - loss: 0.1320 - mean_absolute_error: 0.2228 - mean_squared_error: 0.1320
# Epoch 21/30
# 5000/5000 - 0s - loss: 0.1454 - mean_absolute_error: 0.2335 - mean_squared_error: 0.1454
# Epoch 22/30
# 5000/5000 - 0s - loss: 0.1203 - mean_absolute_error: 0.2115 - mean_squared_error: 0.1203
# Epoch 23/30
# 5000/5000 - 0s - loss: 0.1111 - mean_absolute_error: 0.2017 - mean_squared_error: 0.1111
# Epoch 24/30
# 5000/5000 - 0s - loss: 0.2894 - mean_absolute_error: 0.2656 - mean_squared_error: 0.2894
# Epoch 25/30
# 5000/5000 - 0s - loss: 0.0942 - mean_absolute_error: 0.1854 - mean_squared_error: 0.0942
# Epoch 26/30
# 5000/5000 - 0s - loss: 0.0914 - mean_absolute_error: 0.1840 - mean_squared_error: 0.0914
# Epoch 27/30
# 5000/5000 - 0s - loss: 0.0796 - mean_absolute_error: 0.1731 - mean_squared_error: 0.0796
# Epoch 28/30
# 5000/5000 - 0s - loss: 0.0799 - mean_absolute_error: 0.1749 - mean_squared_error: 0.0799
# Epoch 29/30
# 5000/5000 - 0s - loss: 0.0658 - mean_absolute_error: 0.1590 - mean_squared_error: 0.0658
# Epoch 30/30
# 5000/5000 - 0s - loss: 0.0637 - mean_absolute_error: 0.1567 - mean_squared_error: 0.0637

# %%
num_shap_samples=100

# %%
primal_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='mobius')
primal_effects = primal_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]WARNING: Logging before flag parsing goes to stderr.
# W1023 13:57:52.320119 140425592383296 base_layer.py:1814] Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 100%|██████████| 100/100 [00:17<00:00,  5.88it/s]

# %%
dual_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='comobius')
dual_effects = dual_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
# 100%|██████████| 100/100 [00:16<00:00,  6.12it/s]

# %%
average_explainer = MarginalExplainer(model, X[num_shap_samples:], nsamples=800, representation='average')
average_effects = average_explainer.explain(X[:num_shap_samples], verbose=True)
# Out:
# 100%|██████████| 100/100 [00:31<00:00,  3.17it/s]

# %%
model_func = lambda x: model(x).numpy()
kernel_explainer = shap.SamplingExplainer(model_func, X)
kernel_shap = kernel_explainer.shap_values(X[:num_shap_samples])
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
def unroll(x):
    ret = []
    for i in range(x.shape[-1]):
        ret.append(x[:, i])
    return np.concatenate(ret)

# %%
data_df = pd.DataFrame({
    'Sampled Primal Effects':  unroll(primal_effects),
    'Sampled Dual Effects':    unroll(dual_effects),
    'Sampled Average Effects': unroll(average_effects),
    'Kernel SHAP Values':      unroll(kernel_shap),
    'Primal Interaction Effects':  unroll(kernel_shap - primal_effects),
    'Dual Interaction Effects':    unroll(kernel_shap - dual_effects),
    'Average Interaction Effects': unroll(kernel_shap - average_effects),
    'Feature': [int(i / num_shap_samples) for i in range(num_shap_samples * d)],
    'Feature Value': unroll(X[:num_shap_samples])
})

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Sampled Primal Effects:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Kernel SHAP Values:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(data_df).mark_point(filled=True).encode(
    alt.Y('Primal Interaction Effects:Q'),
    alt.X('Feature Value:Q'),
    alt.Color('Feature:N'),
    alt.Facet('Feature:N')
).properties(
    columns=3,
    width=200,
    height=200
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
plot.summary_plot(kernel_shap, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
plot.summary_plot(primal_effects, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
plot.summary_plot(kernel_shap - primal_effects, X[:num_shap_samples], plot_type='bar', xlim=(0.0, 1.0))

# %%
ind_df = pd.DataFrame({
    'Primal Main Effect': primal_effects[0],
    'Interaction Effect': kernel_shap[0] - primal_effects[0],
    'Feature': np.arange(kernel_shap.shape[1])
})

melted_df = pd.melt(ind_df, id_vars=['Feature'], value_name='Kernel SHAP Value', var_name='Effect Type')

# %%
alt.Chart(melted_df).mark_bar().encode(
    alt.X('sum(Kernel SHAP Value):Q'),
    alt.Y('Feature:N', sort=alt.EncodingSortField(
            field="Kernel SHAP Value",
            order="descending" 
        ))
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(melted_df).mark_bar().encode(
    alt.X('Kernel SHAP Value:Q'),
    alt.Y('Feature:N', sort=list(np.argsort(kernel_shap[0])[::-1])),
    alt.Color('Effect Type:N', scale=alt.Scale(scheme='dark2'))
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
