# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from build_model import interaction_model, get_subnetwork
from utils import get_interaction_model
from interactions import return_interaction_function

# %%
from path_explain import utils, PathExplainerTF, scatter_plot, summary_plot
utils.set_up_environment(visible_devices='5')

# %%
x = np.random.randn(2000, 5).astype(np.float32)
y = 2 * x[:, 0] * x[:, 1] - \
    x[:, 0] * x[:, 2] + \
    1.5 * x[:, 2] * x[:, 3] + \
    0.5 * x[:, 1] * x[:, 3] + \
    x[:, 4]

# %%
model = get_interaction_model(x, y)
# Out:
# Train on 1600 samples
# Epoch 1/50
# 1600/1600 [==============================] - 0s 221us/sample - loss: 5.2016 - mean_squared_error: 5.2016
# Epoch 2/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 2.7179 - mean_squared_error: 2.7179
# Epoch 3/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 1.8460 - mean_squared_error: 1.8460
# Epoch 4/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 1.2044 - mean_squared_error: 1.2044
# Epoch 5/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.8077 - mean_squared_error: 0.8077
# Epoch 6/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.6286 - mean_squared_error: 0.6286
# Epoch 7/50
# 1600/1600 [==============================] - 0s 14us/sample - loss: 0.4417 - mean_squared_error: 0.4417
# Epoch 8/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.3759 - mean_squared_error: 0.3759
# Epoch 9/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.2896 - mean_squared_error: 0.2896
# Epoch 10/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.2366 - mean_squared_error: 0.2366
# Epoch 11/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.1909 - mean_squared_error: 0.1909
# Epoch 12/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.1781 - mean_squared_error: 0.1781
# Epoch 13/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.1708 - mean_squared_error: 0.1708
# Epoch 14/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.1482 - mean_squared_error: 0.1482
# Epoch 15/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.1279 - mean_squared_error: 0.1279
# Epoch 16/50
# 1600/1600 [==============================] - 0s 14us/sample - loss: 0.1128 - mean_squared_error: 0.1128
# Epoch 17/50
# 1600/1600 [==============================] - 0s 11us/sample - loss: 0.1024 - mean_squared_error: 0.1024
# Epoch 18/50
# 1600/1600 [==============================] - 0s 11us/sample - loss: 0.0975 - mean_squared_error: 0.0975
# Epoch 19/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0894 - mean_squared_error: 0.0894
# Epoch 20/50
# 1600/1600 [==============================] - 0s 14us/sample - loss: 0.0806 - mean_squared_error: 0.0806
# Epoch 21/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0758 - mean_squared_error: 0.0758
# Epoch 22/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0714 - mean_squared_error: 0.0714
# Epoch 23/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0692 - mean_squared_error: 0.0692
# Epoch 24/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0653 - mean_squared_error: 0.0653
# Epoch 25/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0643 - mean_squared_error: 0.0643
# Epoch 26/50
# 1600/1600 [==============================] - 0s 11us/sample - loss: 0.0631 - mean_squared_error: 0.0631
# Epoch 27/50
# 1600/1600 [==============================] - 0s 11us/sample - loss: 0.0598 - mean_squared_error: 0.0598
# Epoch 28/50
# 1600/1600 [==============================] - 0s 11us/sample - loss: 0.0573 - mean_squared_error: 0.0573
# Epoch 29/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0586 - mean_squared_error: 0.0586
# Epoch 30/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0570 - mean_squared_error: 0.0570
# Epoch 31/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0525 - mean_squared_error: 0.0525
# Epoch 32/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0514 - mean_squared_error: 0.0514
# Epoch 33/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0514 - mean_squared_error: 0.0514
# Epoch 34/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0501 - mean_squared_error: 0.0501
# Epoch 35/50
# 1600/1600 [==============================] - 0s 14us/sample - loss: 0.0490 - mean_squared_error: 0.0490
# Epoch 36/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0481 - mean_squared_error: 0.0481
# Epoch 37/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0462 - mean_squared_error: 0.0462
# Epoch 38/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0466 - mean_squared_error: 0.0466
# Epoch 39/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0445 - mean_squared_error: 0.0445
# Epoch 40/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0444 - mean_squared_error: 0.0444
# Epoch 41/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0443 - mean_squared_error: 0.0443
# Epoch 42/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0436 - mean_squared_error: 0.0436
# Epoch 43/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0432 - mean_squared_error: 0.0432
# Epoch 44/50
# 1600/1600 [==============================] - 0s 13us/sample - loss: 0.0426 - mean_squared_error: 0.0426
# Epoch 45/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0427 - mean_squared_error: 0.0427
# Epoch 46/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0429 - mean_squared_error: 0.0429
# Epoch 47/50
# 1600/1600 [==============================] - ETA: 0s - loss: 0.0375 - mean_squared_error: 0.03 - 0s 12us/sample - loss: 0.0416 - mean_squared_error: 0.0416
# Epoch 48/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0422 - mean_squared_error: 0.0422
# Epoch 49/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0418 - mean_squared_error: 0.0418
# Epoch 50/50
# 1600/1600 [==============================] - 0s 12us/sample - loss: 0.0410 - mean_squared_error: 0.0410
# 400/400 - 0s - loss: 0.0758 - mean_squared_error: 0.0758

# %%
predicted_y = model.predict(x)

# %%
plt.scatter(y, predicted_y)

# %%
interpret_model = tf.keras.models.clone_model(model)
interpret_model.set_weights(model.get_weights())
for layer in interpret_model.layers:
    if layer.get_config().get('activation', None) == 'relu':
        layer.activation = utils.softplus_activation(beta=10.0)

# %%
explainer = PathExplainerTF(interpret_model)

baseline = np.zeros((1, x.shape[1])).astype(np.float32)
interactions = explainer.interactions(inputs=x[:200],
                                      baseline=baseline,
                                      batch_size=100,
                                      num_samples=100,
                                      use_expectation=False,
                                      output_indices=0,
                                      verbose=True,
                                      interaction_index=None)
# Out:
# 100%|██████████| 200/200 [02:10<00:00,  1.53it/s]

# %%
attributions = np.sum(interactions, axis=-1)

# %%
summary_plot(attributions,
             x[:200])

# %%
fig, axs = scatter_plot(attributions,
                        x[:200],
                        feature_index=0,
                        interactions=interactions,
                        color_by=4,
                        feature_names=None,
                        scale_y_ind=True)

# %%
np.mean(np.abs(interactions), axis=0)
# Out:
# array([[0.17454072, 0.17087816, 0.00648498, 0.02050547, 0.00806674],
#        [0.17087816, 0.1745632 , 0.00587985, 0.0237739 , 0.00786588],
#        [0.00648498, 0.00587985, 0.00956019, 0.00309727, 0.00176144],
#        [0.02050547, 0.0237739 , 0.00309727, 0.35621677, 0.00548609],
#        [0.00806674, 0.00786588, 0.00176144, 0.00548609, 0.01260004]])
