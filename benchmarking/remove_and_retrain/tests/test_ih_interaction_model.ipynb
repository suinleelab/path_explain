# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import tensorflow as tf
import numpy as np
from build_model import interaction_model, get_subnetwork

# %%
from path_explain import utils, PathExplainerTF
utils.set_up_environment(visible_devices='3')

# %%
model = interaction_model(num_features=23,
                          num_layers=2,
                          hidden_layer_size=4,
                          num_outputs=1,
                          activation_function=tf.keras.activations.relu,
                          interactions_to_ignore=None)

# %%
subnetwork = get_subnetwork(model, (0, 1))

# %%
explainer = PathExplainerTF(subnetwork)

# %%
inputs   = np.random.randn(10, 2).astype(np.float32)
baseline = np.zeros((1, 2)).astype(np.float32)

# %%
interactions = explainer.interactions(inputs,
                                      baseline,
                                      batch_size=100,
                                      num_samples=100,
                                      use_expectation=False,
                                      output_indices=0,
                                      verbose=True)
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  6.36it/s]

# %%
interactions.shape

# %%
interactions.shape
# Out:
# (10, 15, 15)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              [(None, 23)]         0
# __________________________________________________________________________________________________
# select_0 (Dense)                (None, 1)            23          input[0][0]
# __________________________________________________________________________________________________
# select_1 (Dense)                (None, 1)            23          input[0][0]
# __________________________________________________________________________________________________
# select_2 (Dense)                (None, 1)            23          input[0][0]
# __________________________________________________________________________________________________
# select_3 (Dense)                (None, 1)            23          input[0][0]
# ...
